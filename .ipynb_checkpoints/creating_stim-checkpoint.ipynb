# %%
import math
import numpy as np
import pandas as pd
from pathlib import Path

# %%
datafile = Path('/Users/nico/Documents/GitHub/VST/new_stimuli.csv')

# %%
df = pd.read_csv(datafile)
len(df)
# Out:
# 60

# %%
df2=df.loc[df.index.repeat(2)]
df2
# Out:
#    Condition Index                  Condition Type  \
# 0                a   Facilitation Condition Trials
# 0                a   Facilitation Condition Trials
# 1                a   Facilitation Condition Trials
# 1                a   Facilitation Condition Trials
# 2                a   Facilitation Condition Trials
# ..             ...                             ...
# 57               f  Disengagement Condition Trials
# 58               f  Disengagement Condition Trials
# 58               f  Disengagement Condition Trials
# 59               f  Disengagement Condition Trials
# 59               f  Disengagement Condition Trials
#
#                                   Stimuli Combination      target distractor1  \
# 0       uncertainty word target + non-word distractor       maybe      trrlep
# 0       uncertainty word target + non-word distractor       maybe      trrlep
# 1       uncertainty word target + non-word distractor       vague       wrflz
# ...

# %%
shuffled = df2.sample(frac=1).reset_index()
print(shuffled)
# Out:
#      index Condition Index                  Condition Type  \
# 0       17               d  Disengagement Condition Trials
# 1       40               c   Facilitation Condition Trials
# 2       11               d  Disengagement Condition Trials
# 3       26               b   Facilitation Condition Trials
# 4       56               f  Disengagement Condition Trials
# ..     ...             ...                             ...
# 115     58               f  Disengagement Condition Trials
# 116     51               f  Disengagement Condition Trials
# 117     46               c   Facilitation Condition Trials
# 118     31               e  Disengagement Condition Trials
# 119     34               e  Disengagement Condition Trials
#
#                                    Stimuli Combination     target distractor1  \
# 0        non-word target + uncertainty word distractor    txvdnbb     unknown
# 1                non-word target + non-word distractor      gwyqg       jsghp
# ...

# %%
shuffled.to_csv('shuffled_stimuli.csv', index=False)
