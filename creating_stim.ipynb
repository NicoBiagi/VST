# %%
import math
import numpy as np
import pandas as pd
from pathlib import Path

# %%
datafile = Path('/Users/nico/Documents/GitHub/Experiments/VST/new_stimuli.csv')

# %%
df = pd.read_csv(datafile)
len(df)
# Out:
# 60

# %%
df2=df.loc[df.index.repeat(20)]
df2
# Out:
#                     Condition Type  \
# 0    Facilitation Condition Trials
# 0    Facilitation Condition Trials
# 0    Facilitation Condition Trials
# 0    Facilitation Condition Trials
# 0    Facilitation Condition Trials
# ..                             ...
# 59  Disengagement Condition Trials
# 59  Disengagement Condition Trials
# 59  Disengagement Condition Trials
# 59  Disengagement Condition Trials
# 59  Disengagement Condition Trials
#
#                                   Stimuli Combination Type  \
# 0       uncertainty word target + non-word distractor    a
# 0       uncertainty word target + non-word distractor    a
# 0       uncertainty word target + non-word distractor    a
# 0       uncertainty word target + non-word distractor    a
# 0       uncertainty word target + non-word distractor    a
# ..                                                ...  ...
# 59  uncategorized neutral word target + uncategori...    f
# 59  uncategorized neutral word target + uncategori...    f
# 59  uncategorized neutral word target + uncategori...    f
# 59  uncategorized neutral word target + uncategori...    f
# 59  uncategorized neutral word target + uncategori...    f
#
#                                        stimulus correct_answer
# 0                    maybe,trrlep,trrlep,trrlep              z
# 0                    maybe,trrlep,trrlep,trrlep              z
# 0                    maybe,trrlep,trrlep,trrlep              z
# 0                    maybe,trrlep,trrlep,trrlep              z
# 0                    maybe,trrlep,trrlep,trrlep              z
# ..                                          ...            ...
# 59  skyscraper,unofficial,unofficial,unofficial              z
# 59  skyscraper,unofficial,unofficial,unofficial              z
# 59  skyscraper,unofficial,unofficial,unofficial              z
# 59  skyscraper,unofficial,unofficial,unofficial              z
# 59  skyscraper,unofficial,unofficial,unofficial              z
#
# [1200 rows x 5 columns]

# %%
shuffled = df2.sample(frac=1).reset_index()
print(shuffled)
# Out:
#       index                  Condition Type  \
# 0        59  Disengagement Condition Trials
# 1        46   Facilitation Condition Trials
# 2        29   Facilitation Condition Trials
# 3        59  Disengagement Condition Trials
# 4        41   Facilitation Condition Trials
# ...     ...                             ...
# 1195      3   Facilitation Condition Trials
# 1196     44   Facilitation Condition Trials
# 1197     44   Facilitation Condition Trials
# 1198     18  Disengagement Condition Trials
# 1199      6   Facilitation Condition Trials
#
#                                     Stimuli Combination Type  \
# 0     uncategorized neutral word target + uncategori...    f
# 1                 non-word target + non-word distractor    c
# 2     categorized neutral word target + non-word dis...    b
# 3     uncategorized neutral word target + uncategori...    f
# 4                 non-word target + non-word distractor    c
# ...                                                 ...  ...
# 1195      uncertainty word target + non-word distractor    a
# 1196              non-word target + non-word distractor    c
# 1197              non-word target + non-word distractor    c
# 1198      non-word target + uncertainty word distractor    d
# 1199      uncertainty word target + non-word distractor    a
#
#                                          stimulus correct_answer
# 0     skyscraper,unofficial,unofficial,unofficial              z
# 1                rjuqubbx,jnkwapj,jnkwapj,jnkwapj              m
# 2     dishwasher,ztqtpuoefr,ztqtpuoefr,ztqtpuoefr              z
# 3     skyscraper,unofficial,unofficial,unofficial              z
# 4                         pglql,mnklu,mnklu,mnklu              m
# ...                                           ...            ...
# 1195                  random,tfgnkc,tfgnkc,tfgnkc              z
# 1196                  zjgdys,gwmwql,gwmwql,gwmwql              m
# 1197                  zjgdys,gwmwql,gwmwql,gwmwql              m
# 1198      cgpfdjfrq,uncertain,uncertain,uncertain              m
# 1199              unclear,jhldvfd,jhldvfd,jhldvfd              z
#
# [1200 rows x 6 columns]

# %%
shuffled.to_csv('shuffled_stimuli.csv')
